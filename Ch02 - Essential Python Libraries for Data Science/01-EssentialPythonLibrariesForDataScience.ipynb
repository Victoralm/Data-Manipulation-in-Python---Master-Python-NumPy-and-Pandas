# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## [Pandas](https://pypi.org/project/pandas/)
#
# [ref](https://pandas.pydata.org/)
#
# - Is a Python library for data manipulation and analysis
# - Allows exploring, cleaning and processing tabular data
# - Provides two ways for storing data:
#   - Series, which is one dimensional data structure
#   - Data Frame, which is two dimensional data structure
#   ![01-PandasData.png](attachment:01-PandasData.png)
#
# ## [NumPy](https://numpy.org/doc/stable//reference/routines.lib.html)
#
# - Stands for Numerical Python
# - Provides a data structure called NumPy array, which is a grid of values
# - Also provides a collection of high-level mathematical functions which can be
#   performed on multi-dimensional NumPy arrays. Dataframes can be used as NumPy
#   two dimensional arrays (pandas is built on top of NumPy).
#   ![02-NumPyData.png](attachment:02-NumPyData.png)
#
# ## Pandas vs NumPy
#
# | **NumPy** | **Pandas** |
# | ------ | ----- |
# | Is used for scientific computing | Is used for data manipulation, such as storing, exploring, cleaning and processing data |
# | Provides NumPy arrays which can be multidimensional | Provides two data structures: Series: One dimensional and Dataframes: Two dimensional |
# | Use for Mathematical Computations | Use for data manipulation |
#
# Both are libraries for Data Science.
# Since Pandas Series and Dataframes can be thought as one and two dimensional
# NumPy arrays respectively, we can apply NumPy mathematical functions on them as well.

# %% [markdown]
# ## [Matplotlib](https://matplotlib.org/)
#
# - Is a visualization Python library, used for ploting graphs
# - The pyplot module, inside of Matplotlib provides the interface to underlying
#   plotting functionality of the Matplotlib
# - Allows the creation of a number of different types of graphs using Matplotlib
#   such as line graphs, bar graphs, histograms, scatter plots, area plots, pie
#   plots and so on
# ![03-MatplotlibDataVisualization.png](attachment:03-MatplotlibDataVisualization.png)

# %% [markdown]
# ## [Seaborn](https://seaborn.pydata.org/)
#
# - Another visualization Python library, built on top of Matplotlib
# - Extends the functionality of Matplotlib and allows creating a variety of
#   different graphs with fewer syntax
#   ![04-SeabornDataVisualization.png](attachment:04-SeabornDataVisualization.png)
